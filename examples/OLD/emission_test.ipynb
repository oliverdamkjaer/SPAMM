# %%
from os import path

import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from emission_test import *

# %%
# Define the unit-less wavelength and flux
wave = np.arange(1000, 8000)
ln_wave = np.log(wave)
wave_range = ([wave[0], wave[-1]])

flux_lines, line_names, line_wave = emission_lines(ln_lam_temp=ln_wave, lam_range_gal=wave_range, FWHM_gal=50, pixel=True, limit_doublets=False, vacuum=False)
# Out:
# Emission lines included in gas templates:
# ['H10' 'H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[OII]3726'
#  '[OII]3729' '[SII]6716' '[SII]6731' '[NeIII]3968' '[NeIII]3869'
#  'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']

# %%
flux_lines = np.array(flux_lines)
plt.plot(ln_wave, flux_lines.sum(1));
